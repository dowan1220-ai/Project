# %%
print(3+5)
print('대구', '소마고')

print(-2 - 3)
# Out:
# 8
# 대구 소마고
# -5

# %%
print(2**10)
print(3+5)
print('3+5')

print('대구' + '소마고')
print('대구','소마고')
print('대구' + '3')
print(5*3)
print('대구'*3)
# Out:
# 1024
# 8
# 3+5
# 대구소마고
# 대구 소마고
# 대구3
# 15
# 대구대구대구

# %%
print(5 > 3)
print(5 <= 3)
print(5 == 3)
print(5 != 3)
# Out:
# True
# False
# False
# True

# %%
a = 3
b = 4
c = a + b
print(c)
# Out:
# 7

# %%
a = int(input('첫번째 숫자 :'))
b = int(input('두번째 숫자 :'))
c = a + b
print(c)
# Out:
# 5
