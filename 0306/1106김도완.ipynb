# %%
a = "John's \\ house"
print(a)

# %%
a = 'python'
b = ' is fun'
print(a + b)

# %%
print("="*30)

# %%
print("*"*10)

# %%
a = 'apple'
print(len(a))
a = 'life is too short'
print(a[3])
print(a[5])
print(a[-1])
a = a[0] + a[1] + a[2] + a[3]
print(a)
b=
